# %%
import tiktoken
# tokenizer = tiktoken.get_encoding("cl100k_base")
tokenizer = tiktoken.encoding_for_model("gpt-3.5-turbo-16k")
my_tokens = tokenizer.encode("""目录 \n\n1.  超融合平台架构 .......................................................... 5 \n\n2.  aCloud 平台管理层可靠性 ................................................. 6 \n\n2.1.  分布式架构 .......................................................... 6 \n\n2.2.  网络链路全冗余 ...................................................... 6 \n\n2.3.  系统资源自保障 ...................................................... 7 \n\n2.4.  资源预留保障 ........................................................ 7 \n\n2.5.  监控告警中心 ........................................................ 8 \n\n2.6.  进程看门狗 .......................................................... 8 \n\n2.7.  黑匣子技术 .......................................................... 8 \n\n2.8.  系统文件备份恢复 .................................................... 9 \n\n3.  aSV 计算层可靠性设计 .................................................... 9 \n\n3.1.  虚拟机异常重启 ...................................................... 9 \n\n3.2.  虚拟机高可用 HA ..................................................... 9 \n\n3.3.  虚拟机快照 ......................................................... 10 \n\n3.4.  虚拟机热迁移 ....................................................... 10 \n\n3.5.  主机维护模式 ....................................................... 11 \n\n3.6.  动态资源调度 ....................................................... 11 \n\n3.7.  动态资源扩展 ....................................................... 12 \n\n3.8.  虚拟机优先级 ....................................................... 13 \n\n3.9.  资源回收站 ......................................................... 13 \n\n3.10.  虚拟机互斥保护 ..................................................... 13 \n\n4.  aSAN 存储层可靠性设计 .................................................. 13 \n\n4.1.  aSAN 分布式存储架构 ................................................ 13 \n\n4.2.  数据多副本保护 ..................................................... 14 \n\n4.3.  数据仲裁保护 ....................................................... 15 \n\n4.4.  数据热备盘保护 ..................................................... 15 \n\n4.5.  IO QOS 保护 ........................................................ 16 \n\n4.6.  硬盘亚健康检测 ..................................................... 16 \n\n4.7.  硬盘维护模式 ....................................................... 17 \n\n4.8.  静默错误检测 ....................................................... 17 \n\n4.9.  数据快速重建 ....................................................... 18 \n\n3 \n\n\x0c""")
print(len(my_tokens))
# Out:
# 627
